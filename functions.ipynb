# %%
# split the string into a list of words
strs = "this is the python string"
strs
# Out:
# 'this is the python string'

# %%
strs.strip().split()
# Out:
# ['this', 'is', 'the', 'python', 'string']

# %%
strs.strip()
# Out:
# 'this is the python string'
