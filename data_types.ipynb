# %%
# intiger
a = 1
print(a)
print(type(a))
# Out:
# 1
# <class 'int'>

# %%
# float 
pi = 2.147
print(type(pi))
# Out:
# <class 'float'>

# %%
#string
str = "Hello World"
print(type(str))

# %%
# Boolean
is_valid = True
print(type(is_valid))

# %%
# multiple data types
my_list = [1, 2.5, "Hello", False]
print(type(my_list))
