# %%
pip install pyjokes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pyjoke.exe and pyjokes.exe are installed in 'C:\Users\vipul\AppData\Roaming\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pyjokes

print('printing jocks')
jock = pyjokes.get_joke()
print(jock)
# Out:
# printing jocks
# Why do you always use i and j variales in loops? It's the law......

# %%
pip install pyttsx3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.7 MB 4.0 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.7 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 4.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.7 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.7 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 5.4 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
# ...

# %%
# import pyjokes
# import pyttsx3

# # initialize text-to-speech engine
# engine = pyttsx3.init()

# print("Printing joke...")
# joke = pyjokes.get_joke()

# print(joke)

# # speak the joke
# engine.say(joke)
# engine.runAndWait()

# %%
pip install pyttsx3 pyjokes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pyttsx3

# engine = pyttsx3.init()

# engine.say("You are the best Vipul")
# engine.runAndWait()
